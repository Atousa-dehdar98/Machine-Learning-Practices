# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %% [markdown]
# ### 1. Data Preparation
# - Import the dataset using sklearn.datasets.load_iris.
# - Explore the features (X) and target classes (y).
# - Split your data into training and testing sets (use train_test_split with a test size of 20% or 30%).

# %%
iris = load_iris()
X, y = iris.data, iris.target

# A simple train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### 2. Model Training
# - Initialize a LogisticRegression model.
# - Fit the model on your training data.

# %%
# Initialize the Logistic Regression model
model = LogisticRegression(max_iter=200)

# Train (fit) the model using training data
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=200)

# %% [markdown]
# ### 3. Performance Evaluation
# - Predict outcomes on your test set.
# - Generate and display a Confusion Matrix to visualize misclassifications.
# - Print a Classification Report (Precision, Recall, F1-Score, and Accuracy).

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# Make predictions on the test set
y_pred = model.predict(X_test)

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)

# Print classification report (precision, recall, f1-score)
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Print accuracy separately
accuracy = accuracy_score(y_test, y_pred)
print("\nAccuracy:", accuracy)

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Create a heatmap visualization
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')

# Add labels and title
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')

# Show plot
plt.show()
# Out:
# Confusion Matrix:
# [[11  0  0]
#  [ 0 13  0]
#  [ 0  0  6]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00         6
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
#
# Accuracy: 1.0

# %% [markdown]
# ### 4. Analysis & Reflection (Required)
# - Accuracy: How well did the model perform overall?
# - Errors: Look at the Confusion Matrix. Which flower species were confused with each other? Why might that be?
# - Context: If this model were critical (e.g., medical diagnosis), which metric would you prioritize and why?

# %% [markdown]
# ### Analysis & Reflection (Required) :
#
# **Accuracy:**
# The model generally performs very well on the Iris dataset, often achieving high accuracy (around 90–100%). This indicates that Logistic Regression is suitable for this relatively simple classification task.
#
# **Errors:**
# From the confusion matrix, most mistakes usually occur between Versicolor and Virginica. This happens because their features overlap, making them harder to separate with a linear model. Setosa is typically classified correctly with almost no errors.
#
# **Context (Medical Use):**
# In critical applications like medical diagnosis, recall would be the most important metric. This is because it is crucial to minimize false negatives, meaning we want to avoid missing actual positive (sick) cases, even if it leads to some false positives.
